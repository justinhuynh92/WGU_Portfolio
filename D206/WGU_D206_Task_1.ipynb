# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sb

# importing the churn_raw_data.csv through the file path
df = pd.read_csv('/Users/justinhuynh/Desktop/churn_raw_data.csv')
# check all information about this file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10000 non-null  int64
#  1   CaseOrder             10000 non-null  int64
#  2   Customer_id           10000 non-null  object
#  3   Interaction           10000 non-null  object
#  4   City                  10000 non-null  object
#  5   State                 10000 non-null  object
#  6   County                10000 non-null  object
#  7   Zip                   10000 non-null  int64
#  8   Lat                   10000 non-null  float64
#  9   Lng                   10000 non-null  float64
#  10  Population            10000 non-null  int64
#  11  Area                  10000 non-null  object
#  12  Timezone              10000 non-null  object
#  13  Job                   10000 non-null  object
#  14  Children              7505 non-null   float64
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
print(df.duplicated().value_counts())
# Out:
# False    10000
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# CaseOrder               0
# Customer_id             0
# Interaction             0
# City                    0
# State                   0
# County                  0
# Zip                     0
# Lat                     0
# Lng                     0
# Population              0
# Area                    0
# Timezone                0
# Job                     0
# Children                0
# Age                     0
# Education               0
# Employment              0
# Income                  0
# Marital                 0
# Gender                  0
# Churn                   0
# Outage_sec_perweek      0
# Email                   0
# Contacts                0
# Yearly_equip_failure    0
# Techie                  0
# Contract                0
# Port_modem              0
# Tablet                  0
# InternetService         0
# Phone                   0
# Multiple                0
# OnlineSecurity          0
# OnlineBackup            0
# ...

# %%
plt.hist(df['Children'])
plt.show()

# %%
df['Children'].fillna(df['Children'].median(), inplace=True)

# %%
plt.hist(df['Age'])
plt.show()

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
plt.hist(df['Income'])
plt.show()

# %%
df['Income'].fillna(df['Income'].median(), inplace=True)

# %%
plt.hist(df['Tenure'])
plt.show()

# %%
df['Tenure'].fillna(df['Tenure'].median(), inplace=True)

# %%
plt.hist(df['Bandwidth_GB_Year'])
plt.show()

# %%
df['Bandwidth_GB_Year'].fillna(df['Bandwidth_GB_Year'].median(), inplace=True)

# %%
plt.hist(df['Techie'].astype('str'))
plt.show()

# %%
mode_value = df['Techie'].mode()[0]
df['Techie'].fillna(mode_value, inplace=True)

# %%
plt.hist(df['Phone'].astype('str'))
plt.show()

# %%
mode_value = df['Phone'].mode()[0]
df['Phone'].fillna(mode_value, inplace=True)

# %%
plt.hist(df['TechSupport'].astype('str'))
plt.show()

# %%
mode_value = df['TechSupport'].mode()[0]
df['TechSupport'].fillna(mode_value, inplace=True)

# %%
boxplot=sb.boxplot(x='Population',data=df)

# %%
# put outliers into new dataframe called population_query
population_query = df.query('Population > 3000')
# look at number of outliers
population_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4935 entries, 1 to 9999
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            4935 non-null   int64
#  1   CaseOrder             4935 non-null   int64
#  2   Customer_id           4935 non-null   object
#  3   Interaction           4935 non-null   object
#  4   City                  4935 non-null   object
#  5   State                 4935 non-null   object
#  6   County                4935 non-null   object
#  7   Zip                   4935 non-null   int64
#  8   Lat                   4935 non-null   float64
#  9   Lng                   4935 non-null   float64
#  10  Population            4935 non-null   int64
#  11  Area                  4935 non-null   object
#  12  Timezone              4935 non-null   object
#  13  Job                   4935 non-null   object
#  14  Children              3676 non-null   float64
# ...

# %%
boxplot=sb.boxplot(x='Children',data=df)

# %%
# put outliers into new dataframe called children_query
children_query = df.query('Children > 7')
# look at number of outliers
children_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 30 to 9946
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            302 non-null    int64
#  1   CaseOrder             302 non-null    int64
#  2   Customer_id           302 non-null    object
#  3   Interaction           302 non-null    object
#  4   City                  302 non-null    object
#  5   State                 302 non-null    object
#  6   County                302 non-null    object
#  7   Zip                   302 non-null    int64
#  8   Lat                   302 non-null    float64
#  9   Lng                   302 non-null    float64
#  10  Population            302 non-null    int64
#  11  Area                  302 non-null    object
#  12  Timezone              302 non-null    object
#  13  Job                   302 non-null    object
#  14  Children              302 non-null    float64
# ...

# %%
boxplot=sb.boxplot(x='Age',data=df)

# %%
boxplot=sb.boxplot(x='Income',data=df)

# %%
# put outliers into new dataframe called income_query
income_query = df.query('Income > 100000')
# look at number of outliers
income_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299 entries, 13 to 9987
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            299 non-null    int64
#  1   CaseOrder             299 non-null    int64
#  2   Customer_id           299 non-null    object
#  3   Interaction           299 non-null    object
#  4   City                  299 non-null    object
#  5   State                 299 non-null    object
#  6   County                299 non-null    object
#  7   Zip                   299 non-null    int64
#  8   Lat                   299 non-null    float64
#  9   Lng                   299 non-null    float64
#  10  Population            299 non-null    int64
#  11  Area                  299 non-null    object
#  12  Timezone              299 non-null    object
#  13  Job                   299 non-null    object
#  14  Children              227 non-null    float64
# ...

# %%
boxplot=sb.boxplot(x='Outage_sec_perweek',data=df)

# %%
# put outliers into new dataframe called outage_query
outage_query = df.query('Outage_sec_perweek > 25')
# look at number of outliers
outage_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 28 to 9980
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            500 non-null    int64
#  1   CaseOrder             500 non-null    int64
#  2   Customer_id           500 non-null    object
#  3   Interaction           500 non-null    object
#  4   City                  500 non-null    object
#  5   State                 500 non-null    object
#  6   County                500 non-null    object
#  7   Zip                   500 non-null    int64
#  8   Lat                   500 non-null    float64
#  9   Lng                   500 non-null    float64
#  10  Population            500 non-null    int64
#  11  Area                  500 non-null    object
#  12  Timezone              500 non-null    object
#  13  Job                   500 non-null    object
#  14  Children              385 non-null    float64
# ...

# %%
boxplot=sb.boxplot(x='Yearly_equip_failure',data=df)

# %%
# put outliers into new dataframe called equip_fail_query
equip_fail_query = df.query('Yearly_equip_failure > 2')
# look at number of outliers
equip_fail_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94 entries, 8 to 9967
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            94 non-null     int64
#  1   CaseOrder             94 non-null     int64
#  2   Customer_id           94 non-null     object
#  3   Interaction           94 non-null     object
#  4   City                  94 non-null     object
#  5   State                 94 non-null     object
#  6   County                94 non-null     object
#  7   Zip                   94 non-null     int64
#  8   Lat                   94 non-null     float64
#  9   Lng                   94 non-null     float64
#  10  Population            94 non-null     int64
#  11  Area                  94 non-null     object
#  12  Timezone              94 non-null     object
#  13  Job                   94 non-null     object
#  14  Children              73 non-null     float64
# ...

# %%
boxplot=sb.boxplot(x='Tenure',data=df)

# %%
boxplot=sb.boxplot(x='MonthlyCharge',data=df)

# %%
# put outliers into new dataframe called monthlycharge_query
monthlycharge_query = df.query('MonthlyCharge > 290')
# look at number of outliers
monthlycharge_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 798 to 8755
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            18 non-null     int64
#  1   CaseOrder             18 non-null     int64
#  2   Customer_id           18 non-null     object
#  3   Interaction           18 non-null     object
#  4   City                  18 non-null     object
#  5   State                 18 non-null     object
#  6   County                18 non-null     object
#  7   Zip                   18 non-null     int64
#  8   Lat                   18 non-null     float64
#  9   Lng                   18 non-null     float64
#  10  Population            18 non-null     int64
#  11  Area                  18 non-null     object
#  12  Timezone              18 non-null     object
#  13  Job                   18 non-null     object
#  14  Children              12 non-null     float64
# ...

# %%
boxplot=sb.boxplot(x='Bandwidth_GB_Year',data=df)

# %%
# save cleaned data to csv
df.to_csv('cleaned_data.csv')

# %%
# store all quantitative variables in a new data frame for PCA
df_pca = df[['Children', 'Age', 'Income', 'Tenure', 'Population', 'Outage_sec_perweek', 'Yearly_equip_failure', 'MonthlyCharge', 'Bandwidth_GB_Year']]
# fill missing values with mean of each column
df_pca_filled = df_pca.fillna(df_pca.mean())
# normalize columns by subtracting the mean from the value and then dividing by the standard deviation
df_pca_normalized = (df_pca_filled-df_pca_filled.mean())/df_pca_filled.std()
# determine size of the PCA 
pca = PCA(n_components=df_pca_filled.shape[1])
# put normalized data into PCA
pca.fit(df_pca_normalized)
# print data with PCA
pca_print = pd.DataFrame(pca.transform(df_pca_normalized), columns=["PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9"])
# create dataframe for each component
pca_loadings = pd.DataFrame(pca.components_.T, columns = ["PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9"], index=df_pca_normalized.columns)
# print the component loadings
print(pca_loadings)
# Out:
#                            PC1       PC2       PC3       PC4       PC5  \
# Children              0.000556 -0.005230  0.714106  0.001481 -0.082516
# Age                  -0.012202 -0.043172 -0.506465  0.615788  0.217762
# Income                0.005529 -0.000121  0.293582  0.116783  0.801022
# Tenure                0.705104 -0.059268 -0.019660  0.009079  0.007342
# Population            0.000099 -0.060970 -0.279857 -0.452772 -0.209469
# Outage_sec_perweek    0.022728  0.706582  0.039716 -0.024357 -0.010723
# Yearly_equip_failure  0.015615  0.062500  0.232900  0.632695 -0.507374
# MonthlyCharge         0.045550  0.698283 -0.112914 -0.032801  0.051558
# Bandwidth_GB_Year     0.706975 -0.010706  0.008902 -0.010356 -0.001505
#
#                            PC6       PC7       PC8       PC9
# Children              0.043079  0.693493 -0.001822 -0.020530
# Age                   0.081950  0.541661  0.119533  0.021568
# Income                0.447088 -0.235142 -0.057659  0.001180
# ...

# %%
covariance_matrix = np.dot(df_pca_normalized.T, df_pca_normalized) / df_pca.shape[0]
eigenvalues = [np.dot(eigenvector.T, np.dot(covariance_matrix, eigenvector)) for eigenvector in pca.components_]

plt.plot(eigenvalues)
plt.xlabel('Number of Components')
plt.ylabel('Eigenvalues')
plt.axhline(y=1, color='red')
plt.show()
